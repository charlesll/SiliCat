# %%
using SQLite
# Out:
# INFO: Precompiling module SQLite...
# INFO: Recompiling stale cache file /Users/charles/.julia/lib/v0.4/ArrayViews.ji for module ArrayViews.
# INFO: Recompiling stale cache file /Users/charles/.julia/lib/v0.4/DataFrames.ji for module DataFrames.
# INFO: Recompiling stale cache file /Users/charles/.julia/lib/v0.4/Reexport.ji for module Reexport.
# INFO: Recompiling stale cache file /Users/charles/.julia/lib/v0.4/StatsBase.ji for module StatsBase.
# INFO: Recompiling stale cache file /Users/charles/.julia/lib/v0.4/StatsFuns.ji for module StatsFuns.
# INFO: Recompiling stale cache file /Users/charles/.julia/lib/v0.4/DataArrays.ji for module DataArrays.
# INFO: Recompiling stale cache file /Users/charles/.julia/lib/v0.4/GZip.ji for module GZip.
# INFO: Recompiling stale cache file /Users/charles/.julia/lib/v0.4/SortingAlgorithms.ji for module SortingAlgorithms.
# INFO: Recompiling stale cache file /Users/charles/.julia/lib/v0.4/Docile.ji for module Docile.
# WARNING: New definition
# ...

# %%
db = SQLite.DB("../data/viscosity/viscosity.sqlite")
# Out:
# SQLite.DB("../data/viscosity/viscosity.sqlite")

# %%
SQLite.query(db, "SELECT * FROM viscosity")
# Out:
# 5537×19 DataFrames.DataFrame
# │ Row  │ Name                    │ sio2            │ tio2          │
# ├──────┼─────────────────────────┼─────────────────┼───────────────┤
# │ 1    │ Nullable("SiO2")        │ Nullable(100.0) │ Nullable(0.0) │
# │ 2    │ Nullable("SiO2")        │ Nullable(100.0) │ Nullable(0.0) │
# │ 3    │ Nullable("SiO2")        │ Nullable(100.0) │ Nullable(0.0) │
# │ 4    │ Nullable("SiO2")        │ Nullable(100.0) │ Nullable(0.0) │
# │ 5    │ Nullable("SiO2")        │ Nullable(100.0) │ Nullable(0.0) │
# │ 6    │ Nullable("SiO2")        │ Nullable(100.0) │ Nullable(0.0) │
# │ 7    │ Nullable("SiO2")        │ Nullable(100.0) │ Nullable(0.0) │
# │ 8    │ Nullable("SiO2")        │ Nullable(100.0) │ Nullable(0.0) │
# │ 9    │ Nullable("SiO2")        │ Nullable(100.0) │ Nullable(0.0) │
# │ 10   │ Nullable("SiO2")        │ Nullable(100.0) │ Nullable(0.0) │
# │ 11   │ Nullable("SiO2")        │ Nullable(100.0) │ Nullable(0.0) │
# ⋮
# ...
